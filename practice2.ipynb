# %%
from server import mcp, llm_client as client

# %%
res = client.content_engine.generate_lesson_plan(
	topic = "python basics",
	prompt_template='''
	your task is to generate a lesson plan to teach {topic}'''
)
# Out:
# Raw output from LLM:
# ```json
# {
#   "title": "Introduction to Python Programming",
#   "subject": "Computer Science",
#   "learning_objectives": [
#     "Students will be able to explain what Python is and its uses.",
#     "Students will be able to write basic Python commands to print text to the console.",
#     "Students will be able to define and use variables in Python.",
#     "Students will be able to perform basic arithmetic operations in Python.",
#     "Students will be able to understand and use data types like integers, floats, and strings.",
#     "Students will be able to use simple input and output statements."
#   ],
#   "lesson_introduction": "Python is a versatile and popular programming language used in various fields, from web development to data science.  Today, we'll take our first steps into the world of Python! We'll cover the fundamentals that will form the building blocks for more advanced programming concepts.",
#   "main_topics": [
#     {
# ...

# %%
from schema.lessonplan import LessonPlanResponse
print(LessonPlanResponse.model_validate(res.model_dump()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from schema.lessonplan import LessonPlanResponse
# ----> 2 print(LessonPlanResponse.model_validate(res.model_dump()))
#
# NameError: name 'res' is not defined
